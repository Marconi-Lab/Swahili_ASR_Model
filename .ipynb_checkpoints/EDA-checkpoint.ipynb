# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme(style="whitegrid")
import matplotlib.pyplot as plt

# %%
# we create a list of the files we downloaded from common voice apart from audio clips
files = ['validated.tsv','invalidated.tsv','other.tsv','reported.tsv']

# we create an empty dictionary where we will store the contents of each file separately 
dataframes = {}

# run through all the files
for file in files:
    # we read each file in to a dataframe
    df = pd.read_table(file)
    
    # we then add the dataframe to the dictionary with the file name as the key
    dataframes[file] = df

# %% [markdown]
# # Exploring the validated data
#
#
# The validated data is the .tsv file that came together with the the audio clips, invalidated.tsv, others.tsv and reported.tsv when I downloaded the swahili data from common voice as shown on the screen shot below ![swahili](sw).
#
# ### Validated data
# contains the swahili sentences that are validated by volunteers (contributors) on common voice platform.
#
# We need to answer some questions about the data before we can use it for training. Below is a list of the preliminary questions we aim to answer about this validated data ahead of :
# 1. How many sentences have been validated?
# 2. How many have the more than three up votes?
# 3. How many are from a female?
# 4. what is the medium/mean age of the people who contributed this dataset?
# 5. Do we have missing data?
# 6. How shall we handle it and why?
# 7. Do we have a client who contributed more than one sentences?
# 8. Which are the topics of the validated sentences?
# 9. Are the samples balanced? Are there more samples from some speakers than others?
# 10. The diversity of the data in terms of accents, age, gender and dialect. How is it in this dataset?

# %%
# we will store the content of validated.tsv file in a variable called validated_data
validated_data = dataframes['validated.tsv']

#we just read the first five rows
validated_data.head()
# Out:
#                                            client_id  \
# 0  109ce2e2aa73581337898e38918a6fe1db807c5b71dcb1...
# 1  120414bea137eab7d14719d6d81501ff21546ca7719b73...
# 2  172282c37f318c5686a85f5a56c444323feac2c8f4ff80...
# 3  2b866fb04e8161a3cb193ab28065fcff1bed0bbf54e41b...
# 4  2b98fb1815f98abbe0b0056954124c6cab373203682114...
#
#                            path  \
# 0  common_voice_sw_36300004.mp3
# 1  common_voice_sw_35895985.mp3
# 2  common_voice_sw_35774990.mp3
# 3  common_voice_sw_35774955.mp3
# 4  common_voice_sw_35085937.mp3
#
#                                             sentence  up_votes  down_votes  \
# 0   idadi ya watoto yatima inaongezeka kwa kasi sana         4           0
# 1  Aidha neno nyambo linamaanisha mtu au kitu au ...         5           0
# 2                  Maskini kusema hawachoki kuchonga        14           0
# 3                   Maneno mema hutowa nyoka pangoni        17           2
# 4              Miaka mitatu ijayo ntakuwa nimemaliza         2           1
#
#         age gender  accents locale  segment
# 0  twenties   male      NaN     sw      NaN
# 1       NaN    NaN      NaN     sw      NaN
# 2       NaN    NaN      NaN     sw      NaN
# 3       NaN    NaN      NaN     sw      NaN
# 4       NaN    NaN      NaN     sw      NaN

# %% [markdown]
# # how is the data distributed:
# so we can answer the question of:
# 1. how many sentences are validated?
# 2. How many missing data exist?

# %%
print(validated_data.info())
print("-----------------------------------------------------------")
print(validated_data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7956 entries, 0 to 7955
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   client_id   7956 non-null   object
#  1   path        7956 non-null   object
#  2   sentence    7956 non-null   object
#  3   up_votes    7956 non-null   int64
#  4   down_votes  7956 non-null   int64
#  5   age         2824 non-null   object
#  6   gender      2817 non-null   object
#  7   accents     0 non-null      float64
#  8   locale      7956 non-null   object
#  9   segment     0 non-null      float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 621.7+ KB
# None
# -----------------------------------------------------------
#           up_votes   down_votes  accents  segment
# count  7956.000000  7956.000000      0.0      0.0
# mean      3.544997     0.882479      NaN      NaN
# std       3.098202     1.192851      NaN      NaN
# min       2.000000     0.000000      NaN      NaN
# 25%       2.000000     0.000000      NaN      NaN
# 50%       2.000000     1.000000      NaN      NaN
# 75%       3.000000     1.000000      NaN      NaN
# max      24.000000    11.000000      NaN      NaN

# %% [markdown]
# # observations:
# 1. we have missing values on age and  gender columns
# 2. we dont have entries in accents and segments
# 3. we have 7956 validated sentences
# 4. We do not need locale column during training

# %% [markdown]
# ### since we dont have any accents or segments in the dataframe,
# we drop those columns

# %%
validated_data.drop(columns=['accents','segment'], inplace= True)

# %% [markdown]
# ### what is locale?

# %%
# single out the locale column from the validated data
locale_content = validated_data['locale']

# Check the number of unique values in the column
if locale_content.nunique() == 1:
    print("All elements in the locale column are the same.")
else:
    print("Elements in the locale column are not all the same.")
# Out:
# All elements in the locale column are the same.

# %% [markdown]
# ### since all elements in the locale column are the same,
# we can also drop  that column

# %%
# remove the locale column from the  original dataframe
del validated_data['locale']

# %% [markdown]
# ### we removed 3 columns (accent and segment -> because they contained null values), (locale because it only contained 'sw' in all it rows). we now have 7 columns from 10.

# %%
#confirming how many columns are now in the validated data
validated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7956 entries, 0 to 7955
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   client_id   7956 non-null   object
#  1   path        7956 non-null   object
#  2   sentence    7956 non-null   object
#  3   up_votes    7956 non-null   int64
#  4   down_votes  7956 non-null   int64
#  5   age         7956 non-null   object
#  6   gender      7956 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 435.2+ KB

# %% [markdown]
# # what is the distribution of female and male on the data and the ages of the entries

# %%
imputing_missing_values = validated_data.fillna(value= {'gender':'unknown', 'age':0}, inplace = True)

# %% [markdown]
#  #### we just replaced NaN in gender column to unknown, and in age column to 0

# %%
#count the occurrences of gender in the validated data
gender_counts = validated_data['gender'].value_counts()

#plot the count against the distribution
by_gender = sns.barplot(x = gender_counts.index, y = gender_counts.values, data = validated_data)

#add labels to the graph
plt.xlabel('Gender distribution')
plt.ylabel('Gender count')
plt.title('Gender Distribution on the validated data')
# Out:
# Text(0.5, 1.0, 'Gender Distribution on the validated data')

# %% [markdown]
# # Observations:
# 1. We have way more females than male
# 2. We have more than 5000 entries that we dont know which gender they came from

# %%
#we do the same for age right?
age_count = validated_data['age'].value_counts()

#plot age 
by_age = sns.barplot(x = age_count.index, y = age_count.values)

#labels to the graph
plt.xlabel('age distribution')
plt.ylabel('age count')
plt.title('age Distribution on the validated data')
# Out:
# Text(0.5, 1.0, 'age Distribution on the validated data')

# %% [markdown]
# # Observations:
# 1. we have a huge number of sentences that we don't know the ages of their contributors. The bar with 0 as its age distribution represents that population.
# 2. we slightly more thirty somethings than twenties.

# %% [markdown]
# # How are the upvotes distributed?

# %%
# slice rows with more than two upvotes
more_than2_upvotes = validated_data[validated_data['up_votes'] > 2]

#how many are they?
print("Entries with more than 2 up votes are ," + str(len(more_than2_upvotes)))

more_than2_downvotes = validated_data[validated_data['down_votes'] > 2]

print("Entries with more than 2 down votes are ," + str(len(more_than2_downvotes)))
# Out:
# Entries with more than 2 up votes are ,3390
# Entries with more than 2 down votes are ,515

# %% [markdown]
# # What is the distribution of speakers like?
#
# 1. do we have multiple speakers?

# %%
#create a variable to store the unique IDs 
unique_ids = validated_data['client_id'].nunique()

#we then print out a comparison of those IDs versus the total number of IDs
print("We have ", unique_ids, "unique IDs. Out of a total of " + str(len(validated_data['client_id'])) + " IDs")
# Out:
# We have  216 unique IDs. Out of a total of 7956 IDs

# %%
# group the validated data by unique id and get the mean of upvotes and downvotes
grouped_data = validated_data.groupby(['client_id'])[['up_votes','down_votes']].mean()
print("This is the grouped data\n ", grouped_data.head())

# get the top 10 unique ids
top_10_ids = grouped_data.nlargest(10,'up_votes')
print("\n And this is the top 10 in order of up_votes \n" , top_10_ids)

# create the bar plots
top_10_ids.plot(kind='box', stacked=True)

# add labels and title
plt.xlabel('Unique IDs')
plt.ylabel('Votes')
plt.title('Mean of Upvotes and Downvotes for Top 10 Unique IDs', fontsize = 20)

# show the plot
plt.show()
# Out:
# This is the grouped data
#                                                       up_votes  down_votes
# client_id
# 00a577a6e13d02ce2dc80c2e94bd28c437f91f8b1a43fa2...  4.130435    1.913043
# 01e4797f3d71b35d2f0e5cdacd4e1bd83922da7a8c375c3...  3.285714    0.142857
# 040e1a31dbf6e0e12cdf36fef8128c3d7ddcddfdfd930bb...  3.500000    0.625000
# 044fd6e346e984fd6e1b3f0e2bfdf9f906b05de6e2f4dc8...  3.428571    0.190476
# 060e9e622a198ddab7ca519873929bf9c0dfeec5480f54d...  2.123810    0.561905
#
#  And this is top 10 in order of up_votes
#                                                       up_votes  down_votes
# client_id
# 2b866fb04e8161a3cb193ab28065fcff1bed0bbf54e41b1...  17.000000    2.000000
# 172282c37f318c5686a85f5a56c444323feac2c8f4ff80c...  14.000000    0.000000
# 944e043bb81c7577dfc16f0e484fdb0eaebab741787162b...  10.000000    1.000000
# c4bf54f6aa3d2cb0128c105bad197e3c7cd946cb4088745...  10.000000    0.000000
# 9dd0f51e0e64305fbb5629e8df8b859c983769b758ea828...   9.666667    1.333333
# f0c73542ecfe5fd977b2f0ef96901196a4e34fb7f18b500...   9.600000    4.000000
# 6e8efc36879f4bc2d80207c91a1a27d4f15ce4d514df93f...   9.333333    0.666667
# ba1059322a64f8245034bf5b465ba188408709a4ed67776...   9.000000    1.000000
# 3e23dbd1cd3fb1549bb3e878d7427fdedc4ff677d2d2d71...   8.833333    1.555556
# b1117d10db68c8c2010f08b7cfc6ee641392f99b8b4f8b8...   8.800000    2.400000

# %% [markdown]
# # Observations from box plot:
#
# Spread: the boxes are relatively short, meaning that the up and down votes are not that much spread.
#
# Median: the middle value for upvote is close to 10. while the middle value in down vote is below 2.5
#
#
# Outliers: There are the up and downvotes that fall outside of the range of most of the data (outliers).
#
# Skewness:looks like the boxes are not skewed to the left nor to the right as the boxes fall on the line
#
# Comparison: the up and down votes are similiarly distributed since they have relatively same sizes but have different mean.

# %% [markdown]
# # Which are the most frequent words? The distribution of words.
#
# #### we choose visualization - word cloud

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /home/antonym/anaconda3/lib/python3.9/site-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in /home/antonym/anaconda3/lib/python3.9/site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in /home/antonym/anaconda3/lib/python3.9/site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: numpy>=1.6.1 in /home/antonym/anaconda3/lib/python3.9/site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/antonym/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/antonym/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in /home/antonym/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/antonym/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/antonym/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/antonym/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: six>=1.5 in /home/antonym/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

# create a list of sentences from the column 'sentences'
text = validated_data['sentence'].tolist()

# Join all the sentences in the list into one string
text = " ".join(text)

# Create a wordcloud object
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(text)

# Plot the wordcloud
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# # Exploring the audio files:
# Here are some of the questions we shall ask in order to understand the audio samples (from common voice) that we shall use to show a computer to hear swahili audio.
#
# 1. What are the distribution of the audio files' duration? Are there any outliers?
# 2. Are the samples recorded in different environments?
# 3. Are all swahili samples?
# 4. Are there any samples with low or high volume?
# 5. Are there any errors in the transcription?
# 6. Are there any samples with multiple speakers?

# %%
pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      |████████████████████████████████| 214 kB 162 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.0 in /home/antonym/anaconda3/lib/python3.9/site-packages (from librosa) (1.20.3)
# Requirement already satisfied: packaging>=20.0 in /home/antonym/anaconda3/lib/python3.9/site-packages (from librosa) (21.3)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 30 kB/s eta 0:00:012
# Collecting resampy>=0.2.2
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 20 kB/s eta 0:00:01
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/antonym/anaconda3/lib/python3.9/site-packages (from librosa) (1.0.2)
# Requirement already satisfied: decorator>=4.0.10 in /home/antonym/anaconda3/lib/python3.9/site-packages (from librosa) (4.4.2)
# Requirement already satisfied: scipy>=1.2.0 in /home/antonym/anaconda3/lib/python3.9/site-packages (from librosa) (1.7.3)
# Collecting soundfile>=0.10.2
#   Downloading soundfile-0.11.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numba>=0.45.1 in /home/antonym/anaconda3/lib/python3.9/site-packages (from librosa) (0.55.1)
# Requirement already satisfied: joblib>=0.14 in /home/antonym/anaconda3/lib/python3.9/site-packages (from librosa) (1.1.0)
# Collecting pooch>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 31 kB/s eta 0:00:01
# Requirement already satisfied: setuptools in /home/antonym/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (61.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/antonym/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (0.38.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/antonym/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->librosa) (3.0.4)
# Requirement already satisfied: requests>=2.19.0 in /home/antonym/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: appdirs>=1.3.0 in /home/antonym/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/antonym/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/antonym/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.9.24)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/antonym/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/antonym/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/antonym/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/antonym/anaconda3/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /home/antonym/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23706 sha256=5d03fcc59cb8f94e43e184ebf6a3311507d2b7ac337468badc6198559bf6278e
#   Stored in directory: /home/antonym/.cache/pip/wheels/e4/76/a4/cfb55573167a1f5bde7d7a348e95e509c64b2c3e8f921932c3
# Successfully built audioread
# Installing collected packages: soundfile, resampy, pooch, audioread, librosa
# Successfully installed audioread-3.0.0 librosa-0.9.2 pooch-1.6.0 resampy-0.4.2 soundfile-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#used for loading audio files
import librosa

#glob is used to get a list of paths
import glob

import os

# %%
#testing out loading a single audio using IPython
import IPython

#The explainer video is just a 29 seconds audio I downloaded from youtube -> https://www.youtube.com/watch?v=JzPfMbG1vrE
IPython.display.Audio(r'/home/antonym/Documents/Marconi_Lab/Swahili_ASR_Model/ExplainerVideo.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#the directory with the swahili clips
audioclips_directory ="~/Documents/Marconi_Lab/coquistuff/venv-stt/clips"

#initialize empty lists where we shall populate the sample rates and the audio samples
audio_samples = []
sample_rates = []

#get a list of file paths
#file_paths = glob.glob(audioclips_directory)
file_paths = [os.path.join(audioclips_directory, file) for file in os.listdir(audioclips_directory)]


#loop through all the audio samples as you append them into the empty list accordingly
for file_path in file_paths:
    try:
        audio, sr = librosa.load(file_path)
        audio_samples.append(audio)
        sample_rates.append(sr)
    except Exception as e:
        print(f"Error occured while processing {file_path} : {e}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [9], in <cell line: 10>()
#       6 sample_rates = []
#       8 #get a list of file paths
#       9 #file_paths = glob.glob(audioclips_directory)
# ---> 10 file_paths = [os.path.join(audioclips_directory, file) for file in os.listdir(audioclips_directory)]
#      13 #loop through all the audio samples as you append them into the empty list accordingly
#      14 for file_path in file_paths:
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/Documents/Marconi_Lab/coquistuff/venv-stt/clips'

# %%
file_paths = [os.path.join(audioclips_directory, file) for file in os.listdir(audioclips_directory)]

# %%
pip install torchaudio
# Out:
# Requirement already satisfied: torchaudio in /home/antonym/anaconda3/lib/python3.9/site-packages (0.13.1)
# Requirement already satisfied: torch==1.13.1 in /home/antonym/anaconda3/lib/python3.9/site-packages (from torchaudio) (1.13.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/antonym/anaconda3/lib/python3.9/site-packages (from torch==1.13.1->torchaudio) (11.10.3.66)
# Requirement already satisfied: typing-extensions in /home/antonym/anaconda3/lib/python3.9/site-packages (from torch==1.13.1->torchaudio) (4.3.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/antonym/anaconda3/lib/python3.9/site-packages (from torch==1.13.1->torchaudio) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/antonym/anaconda3/lib/python3.9/site-packages (from torch==1.13.1->torchaudio) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/antonym/anaconda3/lib/python3.9/site-packages (from torch==1.13.1->torchaudio) (11.7.99)
# Requirement already satisfied: setuptools in /home/antonym/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->torchaudio) (61.2.0)
# Requirement already satisfied: wheel in /home/antonym/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->torchaudio) (0.37.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
len(audio_samples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 len(audio_samples)
#
# NameError: name 'audio_samples' is not defined

# %%
# what is the duration of each clip?

# %%
# calculate the duration of each clip
clips_duration = [librosa.get_duration(clip) for clip in audio_samples]

# plot the density of the durations
sns.kdeplot(clips_duration, shade=True)

# add labels and title
plt.xlabel('Duration (s)')
plt.ylabel('Density')
plt.title('Distribution of Audio Clip Durations')

# show the plot
plt.show()

# %% [markdown]
# # Lets load the audio files using pydub, then convert them to wav files, then convert them to MFCCs.

# %%
pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# audio segment will help us load the audio clips
from pydub import AudioSegment

# declare the directory that contains the audio files
audio_files_directory = "/home/antonym/Documents/Marconi_Lab/Swahili_ASR_Model/clips/"

#create an empty list that we shall use to store the files from our directory
list_of_audiofiles = []

#iterate through the audio files

for audiofile in os.listdir(audio_files_directory):
    #we now load the mp3 file in the audio file directory
    file_path = os.path.join(audio_files_directory, audiofile)
    
    #load the audio file using audiosegment method
    audio = AudioSegment.from_mp3(file_path)
    
    #add the audio to the empty list of audio files we created above
    list_of_audiofiles.append(audio)

# %%
#print the length of the audio file
print(len(list_of_audiofiles))
# Out:
# 57

# %% [markdown]
# # we have 57 files because,
#
# we did not add all of them as we had downloaded them from common voice. We wanted to just see whether we could load the audio clips in the first place. Now that we can, lets see whether we can do some preprocessing.

# %%
#let explore the first audio file
print("Length of the first audio file is " + str(len(list_of_audiofiles[0])))
print("with a sample rate of " +str(list_of_audiofiles[0].frame_rate))
print("and " +str(list_of_audiofiles[0].channels) + " channels")
print("with a sample width of " +str(list_of_audiofiles[0].sample_width))
print('The frame width in bytes = ' +str(list_of_audiofiles[0].frame_width))
print('lasty, the duration of the first audio clip is ' +str(list_of_audiofiles[0].duration_seconds) + " seconds, or " +str(len(list_of_audiofiles[0])) + " ms")
# Out:
# Length of the first audio file is 7200
# with a sample rate of 32000
# and 1 channels
# with a sample width of 2
# The frame width in bytes = 2
# lasty, the duration of the first audio clip is 7.2 seconds, or 7200 ms

# %% [markdown]
# # lets use a function instead of sequential lines of code for re-usability

# %%
# the function takes in audio file
def load_audiofiles(audio_directory):
    #create an empty list to add the files
    audio_clips = []
    
    #iterate through all the clips in the directory
    for clip in os.listdir(audio_directory):
        #load the audio
        audio_path =

# %%
# lets loop through the files that are now in the list of audio files

for audio_clip in list_of_audiofiles:
    #convert the clips into wav files using the export method found in pydub
    wav_files = audio_clip.export(format='wav')

# %% [markdown]
# # exploring invalidated data

# %%
invalidated_data = dataframes['invalidated.tsv']
invalidated_data.head()

# %%
invalidated_data.info()

# %% [markdown]
# # Exploring other files

# %%
# this is one of the file contained in the zip folder I downloaded from common voice
other_file = dataframes['other.tsv']
other_file.head()
# Out:
#                                            client_id  \
# 0  aecdf573e8bd61d1a795e1eb620b6332a2ae5d4d501a2e...
# 1  dbfe4f658430812c2ff2076e174cc723736262c48f79b1...
# 2  7f8a71e91f9083f87fc16491257a0ddbaf2003bfafc5dd...
# 3  64c154b91aa964192ef24b276d01af045ed7d0556af9d1...
# 4  aecdf573e8bd61d1a795e1eb620b6332a2ae5d4d501a2e...
#
#                            path  \
# 0  common_voice_sw_35085410.mp3
# 1  common_voice_sw_35085509.mp3
# 2  common_voice_sw_35085546.mp3
# 3  common_voice_sw_35085637.mp3
# 4  common_voice_sw_35085682.mp3
#
#                                             sentence  up_votes  down_votes  \
# 0  na hii ni moja ya njia ya kushughulikia masual...         1           1
# 1                   za kuongoza tu kwa mihula miwili         1           1
# 2                                      Mama ni mkali         1           1
# 3  elfu tisa mia saba hamsini na tano nukta sita ...         1           1
# 4  haki za binadamu hazikuzingatiwa kabisa katika...         1           1
#
#    age gender  accents locale  segment
# 0  NaN    NaN      NaN     sw      NaN
# 1  NaN    NaN      NaN     sw      NaN
# 2  NaN    NaN      NaN     sw      NaN
# 3  NaN    NaN      NaN     sw      NaN
# 4  NaN    NaN      NaN     sw      NaN

# %%
other_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53029 entries, 0 to 53028
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   client_id   53029 non-null  object
#  1   path        53029 non-null  object
#  2   sentence    53029 non-null  object
#  3   up_votes    53029 non-null  int64
#  4   down_votes  53029 non-null  int64
#  5   age         19422 non-null  object
#  6   gender      19280 non-null  object
#  7   accents     0 non-null      float64
#  8   locale      53029 non-null  object
#  9   segment     0 non-null      float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 4.0+ MB
